# %%
import numpy as np

def __init__(self, learning_rate = 0.01, num_iterations = 1000):
    self.learning_rate = learning_rate
    self.num_iterations = num_iterations
    self.weights = None
    self.bias = None

# %%
def fit(self, x, y):
    self.x = x
    self.y = y
    number_samples = x.shape()
    number_features = x.shape()
    self.weights = np.zeroes(number_features)
    self.bias = 0
    for i in range(self.iterations):
        y_predicted = np.dot(self.weights,x) + self.bias
        # compute gradients
        dw = (1/number_samples) * np.dot(x.T, (y_predicted-y))
        db = (1/number_samples) * np.sum(y_predicted-y)

        self.weights = self.weights - self.learning_rate * dw
        self.bias = self.bias - self.learning_rate * db

# %%
def predict(self, x, y):
    return np.dot(X, self.weights) + self.bias

# %%
# Generating Synthetic Data

np.random.seed(42)
x = 6 * np.random.rand(100,1)
y = 5 + (3 * x) + np.random.rand(100,1)
#x,y

# %%
import sklearn.linear_model
from sklearn.linear_model import LinearRegression

linear_regression = LinearRegression()
linear_regression.fit(x,y)

x_new = np.array([[0],[2]])
predictions = linear_regression.predict(x_new)
predictions
# Out:
# array([[ 5.51359766],
#        [11.50242044]])

# %%
import matplotlib.pyplot

matplotlib.pyplot.figure(figsize=(8,6))
matplotlib.pyplot.scatter(x,y,color = 'y')
matplotlib.pyplot.plot(x,linear_regression.predict(x), color = 'k')
matplotlib.pyplot.title("LinearRegression")
matplotlib.pyplot.show()
